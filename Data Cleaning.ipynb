# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('loan_data.csv')
df
# Out:
#       credit.policy             purpose  int.rate  installment  \
# 0                 1  debt_consolidation    0.1189       829.10
# 1                 1         credit_card    0.1071       228.22
# 2                 1  debt_consolidation    0.1357       366.86
# 3                 1  debt_consolidation    0.1008       162.34
# 4                 1         credit_card    0.1426       102.92
# ...             ...                 ...       ...          ...
# 9573              0           all_other    0.1461       344.76
# 9574              0           all_other    0.1253       257.70
# 9575              0  debt_consolidation    0.1071        97.81
# 9576              0    home_improvement    0.1600       351.58
# 9577              0  debt_consolidation    0.1392       853.43
#
#       log.annual.inc    dti  fico  days.with.cr.line  revol.bal  revol.util  \
# 0          11.350407  19.48   737        5639.958333      28854        52.1
# ...

# %%
del df['purpose']
del df['dti']
del df['inq.last.6mths']
del df['installment']
del df['days.with.cr.line']

# %%
df.columns = ['MeetsCreditPolicy?', 'InterestRate', 'LogAnnualIncome', 'FICOScore', 'RevolvingBalance', 'RevolvingLineUtilisationRate', 'No. of Overdue Payments', 'NoofDerogatoryPublicRecords', 'LoanFullyPaid?']

# %%
null_values = df.isnull().sum()
null_values # There are no null values!
# Out:
# MeetsCreditPolicy?              0
# InterestRate                    0
# LogAnnualIncome                 0
# FICOScore                       0
# RevolvingBalance                0
# RevolvingLineUtilisationRate    0
# No. of Overdue Payments         0
# NoofDerogatoryPublicRecords     0
# LoanFullyPaid?                  0
# dtype: int64

# %%
df['MeetsCreditPolicy?'].unique()
# Out:
# array([1, 0])

# %%
df['LoanFullyPaid?'].unique()
# Out:
# array([0, 1])

# %%
df['MeetsCreditPolicy?'].unique()
# Out:
# array([1, 0])

# %%
df.columns = ['Meets Credit Policy?', 'Interest Rate (%)', 'Log Annual Income ($)', 'FICO Score', 'Revolving Balance ($)', 'Revolving Line Utilisation Rate', 'No. of Overdue Payments', 'No. of Derogatory Public Records', 'Loan Fully Paid?']

# %%
df['Interest Rate (%)'] *= 100 # Display actual percentage

# %%
df = df.round({'Log Annual Income ($)': 2}) # To 2 decimal places

# %%
df.columns = ['Meets Credit Policy?', 'Interest Rate (%)', 'Log Annual Income ($)', 'FICO Score', 'Revolving Balance ($)', 'Revolving Line Utilisation Rate', 'No. of Overdue Payments', 'No. of Derogatory Public Records', 'Loan Fully Paid?']

# %%
df.columns = ['Meets Credit Policy?', 'Interest Rate (%)', 'Log Annual Income ($)', 'FICO Score', 'Revolving Balance ($)', 'Revolving Line Utilisation Rate', 'No. of Overdue Payments', 'No. of Derogatory Public Records', 'Loan Not Fully Paid']

# %%
df
# Out:
#       Meets Credit Policy?  Interest Rate (%)  Log Annual Income ($)  \
# 0                        1              11.89                  11.35
# 1                        1              10.71                  11.08
# 2                        1              13.57                  10.37
# 3                        1              10.08                  11.35
# 4                        1              14.26                  11.30
# ...                    ...                ...                    ...
# 9573                     0              14.61                  12.18
# 9574                     0              12.53                  11.14
# 9575                     0              10.71                  10.60
# 9576                     0              16.00                  10.82
# 9577                     0              13.92                  11.26
#
#       FICO Score  Revolving Balance ($)  Revolving Line Utilisation Rate  \
# ...

# %%
df.describe() # Statistics like mean average to be later used during visualisation
# Out:
#        Meets Credit Policy?  Interest Rate (%)  Log Annual Income ($)  \
# count           9578.000000        9578.000000            9578.000000
# mean               0.804970          12.264006              10.932345
# std                0.396245           2.684699               0.614834
# min                0.000000           6.000000               7.550000
# 25%                1.000000          10.390000              10.560000
# 50%                1.000000          12.210000              10.930000
# 75%                1.000000          14.070000              11.290000
# max                1.000000          21.640000              14.530000
#
#         FICO Score  Revolving Balance ($)  Revolving Line Utilisation Rate  \
# count  9578.000000           9.578000e+03                      9578.000000
# mean    710.846314           1.691396e+04                        46.799236
# std      37.970537           3.375619e+04                        29.014417
# ...

# %%
df
# Out:
#       Meets Credit Policy?  Interest Rate (%)  Log Annual Income ($)  \
# 0                        1              11.89                  11.35
# 1                        1              10.71                  11.08
# 2                        1              13.57                  10.37
# 3                        1              10.08                  11.35
# 4                        1              14.26                  11.30
# ...                    ...                ...                    ...
# 9573                     0              14.61                  12.18
# 9574                     0              12.53                  11.14
# 9575                     0              10.71                  10.60
# 9576                     0              16.00                  10.82
# 9577                     0              13.92                  11.26
#
#       FICO Score  Revolving Balance ($)  Revolving Line Utilisation Rate  \
# ...

# %%
df.to_csv('FinalLoanData.csv')
